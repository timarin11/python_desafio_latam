# %% [markdown]
# Desafío

# %%
from IPython.display import display, HTML, Image, Audio, Video, Markdown, JSON, Latex

# %%
from IPython.display import Image, display
display (Image(filename='Informaticos.jpg'))
